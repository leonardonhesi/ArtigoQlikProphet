# %%
import pandas as pd

# %%
df = pd.read_csv('2019-1_CA.csv', delimiter=';')
df.head()
# Out:
#   Região - Sigla Estado - Sigla Município                          Revenda  \
# 0             CO             DF  BRASILIA  ABRITTA POSTOS DE SERVIÇOS LTDA
# 1             CO             DF  BRASILIA  ABRITTA POSTOS DE SERVIÇOS LTDA
# 2             CO             DF  BRASILIA  ABRITTA POSTOS DE SERVIÇOS LTDA
# 3             CO             DF  BRASILIA  ABRITTA POSTOS DE SERVIÇOS LTDA
# 4             CO             DF  BRASILIA  ABRITTA POSTOS DE SERVIÇOS LTDA
#
#    CNPJ da Revenda     Produto Data da Coleta Valor de Venda Valor de Compra  \
# 0   10668863000195      DIESEL     16/01/2019          3,799          3,2166
# 1   10668863000195      DIESEL     23/01/2019          3,799             NaN
# 2   10668863000195  DIESEL S10     16/01/2019          3,899          3,2638
# 3   10668863000195  DIESEL S10     23/01/2019          3,899             NaN
# 4   10668863000195      ETANOL     16/01/2019          3,299          2,9999
#
#   Unidade de Medida Bandeira
# ...

# %%
df = df[df['Estado - Sigla'] == 'SP']
df = df[df['Município']      == 'ITU']
df = df[df['Produto']        == 'GASOLINA']
df.head()
# Out:
#        Região - Sigla Estado - Sigla Município  \
# 406381             SE             SP       ITU
# 406382             SE             SP       ITU
# 406431             SE             SP       ITU
# 406432             SE             SP       ITU
# 406433             SE             SP       ITU
#
#                                      Revenda  CNPJ da Revenda   Produto  \
# 406381  ''AUTO POSTO SOLAR DAS TERRAS LTDA''    9259017000132  GASOLINA
# 406382  ''AUTO POSTO SOLAR DAS TERRAS LTDA''    9259017000132  GASOLINA
# 406431            AMIGOS AUTO POSTO ITU LTDA     887870000124  GASOLINA
# 406432            AMIGOS AUTO POSTO ITU LTDA     887870000124  GASOLINA
# 406433            AMIGOS AUTO POSTO ITU LTDA     887870000124  GASOLINA
#
#        Data da Coleta Valor de Venda Valor de Compra Unidade de Medida  \
# 406381     13/02/2019          3,897             NaN        R$ / litro
# 406382     20/02/2019          3,897             NaN        R$ / litro
# ...

# %%
df = df.filter(items=['Bandeira','Revenda','CNPJ da Revenda', 'Data da Coleta', 'Valor de Venda'])
df.head()
# Out:
#         Bandeira                               Revenda  CNPJ da Revenda  \
# 406381    BRANCA  ''AUTO POSTO SOLAR DAS TERRAS LTDA''    9259017000132
# 406382    BRANCA  ''AUTO POSTO SOLAR DAS TERRAS LTDA''    9259017000132
# 406431  IPIRANGA            AMIGOS AUTO POSTO ITU LTDA     887870000124
# 406432  IPIRANGA            AMIGOS AUTO POSTO ITU LTDA     887870000124
# 406433  IPIRANGA            AMIGOS AUTO POSTO ITU LTDA     887870000124
#
#        Data da Coleta Valor de Venda
# 406381     13/02/2019          3,897
# 406382     20/02/2019          3,897
# 406431     02/01/2019          4,599
# 406432     02/04/2019          4,399
# 406433     03/06/2019          4,599

# %%
df.sort_values(by=['CNPJ da Revenda', 'Data da Coleta'])
# Out:
#         Bandeira                                        Revenda  \
# 406431  IPIRANGA                     AMIGOS AUTO POSTO ITU LTDA
# 406432  IPIRANGA                     AMIGOS AUTO POSTO ITU LTDA
# 406433  IPIRANGA                     AMIGOS AUTO POSTO ITU LTDA
# 406434  IPIRANGA                     AMIGOS AUTO POSTO ITU LTDA
# 406435  IPIRANGA                     AMIGOS AUTO POSTO ITU LTDA
# ...          ...                                            ...
# 407660    BRANCA  SATYRO FRANCESCHINELLI & FRANCESCHINELLI LTDA
# 407661    BRANCA  SATYRO FRANCESCHINELLI & FRANCESCHINELLI LTDA
# 407662    BRANCA  SATYRO FRANCESCHINELLI & FRANCESCHINELLI LTDA
# 407663    BRANCA  SATYRO FRANCESCHINELLI & FRANCESCHINELLI LTDA
# 407664    BRANCA  SATYRO FRANCESCHINELLI & FRANCESCHINELLI LTDA
#
#         CNPJ da Revenda Data da Coleta Valor de Venda
# 406431     887870000124     02/01/2019          4,599
# 406432     887870000124     02/04/2019          4,399
# ...

# %%
df['Data da Coleta']    = pd.to_datetime(df['Data da Coleta'])
df                      = df.set_index('Data da Coleta').sort_index()
df                      = df.resample('D').mean().dropna()
df                      = df.reset_index(drop=False)

# %%
df['Data da Coleta'].describe()
# Out:
# count                     364
# unique                     35
# top       2019-06-18 00:00:00
# freq                       14
# first     2019-01-14 00:00:00
# last      2019-12-06 00:00:00
# Name: Data da Coleta, dtype: object

# %%
# first:2019-01-14 last:2019-12-06
time_index = pd.date_range(start='14/01/2019', end='06/12/2019', freq='M')

# %%
df.to_csv('2019-1_CA_ITU.csv')
